# %%
import jqdatasdk as jq

jq.auth('13530336157', 'Qwer4321')  # ID是申请时所填写的手机号；Password为聚宽官网登录密码，新申请用户默认为手机号后6位
# Out:
# auth success

# %%
stocks = jq.get_industry_stocks('sw_l2')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-5edf7e306613> in <module>
# ----> 1 stocks = jq.get_industry_stocks('sw_l2')
#
# C:\ProgramData\Anaconda3\lib\site-packages\jqdatasdk\utils.py in _wrapper(*args, **kwargs)
#     228             print("run jqdatasdk.auth first")
#     229         else:
# --> 230             return func(*args, **kwargs)
#     231     return _wrapper
#     232
#
# C:\ProgramData\Anaconda3\lib\site-packages\jqdatasdk\utils.py in hashable_cached_func(*args, **kwargs)
#     264                 for k, v in kwargs.items()
#     265             }
# --> 266             return copy.deepcopy(cached_func(*_args, **_kwargs))
#     267         hashable_cached_func.cache_info = cached_func.cache_info
#     268         hashable_cached_func.cache_clear = cached_func.cache_clear
#
# C:\ProgramData\Anaconda3\lib\site-packages\jqdatasdk\utils.py in func_with_serialized_params(*args, **kwargs)
#     248             _args = tuple([deserialize(arg) for arg in args])
#     249             _kwargs = {k: deserialize(v) for k, v in six.viewitems(kwargs)}
# --> 250             return func(*_args, **_kwargs)
#     251
#     252         cached_func = cache(func_with_serialized_params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\jqdatasdk\api.py in get_industry_stocks(industry_code, date)
#     192     assert industry_code, "industry_code is required"
#     193     date = to_date_str(date)
# --> 194     return JQDataClient.instance().get_industry_stocks(**locals())
#     195
#     196
#
# C:\ProgramData\Anaconda3\lib\site-packages\jqdatasdk\client.py in <lambda>(**kwargs)
#     167
#     168     def __getattr__(self, method):
# --> 169         return lambda **kwargs: self(method, **kwargs)
#     170
#     171     def get_data_api_url(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\jqdatasdk\client.py in __call__(self, method, **kwargs)
#     162         if result is None:
#     163             if isinstance(err, Exception):
# --> 164                 raise err
#     165
#     166         return result
#
# Exception: 行业板块 'SW_L2' 不存在

# %%
stocks
# Out:
# ['000001.XSHE',
#  '000002.XSHE',
#  '000063.XSHE',
#  '000066.XSHE',
#  '000069.XSHE',
#  '000100.XSHE',
#  '000157.XSHE',
#  '000166.XSHE',
#  '000333.XSHE',
#  '000338.XSHE',
#  '000425.XSHE',
#  '000538.XSHE',
#  '000568.XSHE',
#  '000596.XSHE',
#  '000625.XSHE',
#  '000627.XSHE',
#  '000651.XSHE',
#  '000656.XSHE',
#  '000661.XSHE',
#  '000671.XSHE',
#  '000703.XSHE',
#  '000708.XSHE',
#  '000709.XSHE',
#  '000723.XSHE',
#  '000725.XSHE',
#  '000728.XSHE',
#  '000768.XSHE',
#  '000776.XSHE',
#  '000783.XSHE',
#  '000786.XSHE',
#  '000858.XSHE',
#  '000860.XSHE',
#  '000876.XSHE',
#  '000895.XSHE',
#  '000938.XSHE',
#  '000961.XSHE',
#  '000963.XSHE',
#  '000977.XSHE',
#  '001979.XSHE',
#  '002001.XSHE',
#  '002007.XSHE',
#  '002008.XSHE',
#  '002024.XSHE',
#  '002027.XSHE',
#  '002032.XSHE',
#  '002044.XSHE',
#  '002050.XSHE',
#  '002120.XSHE',
#  '002129.XSHE',
#  '002142.XSHE',
#  '002146.XSHE',
#  '002153.XSHE',
#  '002157.XSHE',
#  '002179.XSHE',
#  '002202.XSHE',
#  '002230.XSHE',
#  '002236.XSHE',
#  '002241.XSHE',
#  '002252.XSHE',
#  '002271.XSHE',
#  '002304.XSHE',
#  '002311.XSHE',
#  '002352.XSHE',
#  '002371.XSHE',
#  '002410.XSHE',
#  '002415.XSHE',
#  '002422.XSHE',
#  '002456.XSHE',
#  '002460.XSHE',
#  '002463.XSHE',
#  '002466.XSHE',
#  '002468.XSHE',
#  '002475.XSHE',
#  '002493.XSHE',
#  '002508.XSHE',
#  '002555.XSHE',
#  '002558.XSHE',
#  '002594.XSHE',
#  '002601.XSHE',
#  '002602.XSHE',
#  '002607.XSHE',
#  '002624.XSHE',
#  '002673.XSHE',
#  '002714.XSHE',
#  '002736.XSHE',
#  '002739.XSHE',
#  '002773.XSHE',
#  '002841.XSHE',
#  '002916.XSHE',
#  '002938.XSHE',
#  '002939.XSHE',
#  '002945.XSHE',
#  '002958.XSHE',
#  '003816.XSHE',
#  '300003.XSHE',
#  '300014.XSHE',
#  '300015.XSHE',
#  '300033.XSHE',
#  '300059.XSHE',
#  '300122.XSHE',
#  '300124.XSHE',
#  '300136.XSHE',
#  '300142.XSHE',
#  '300144.XSHE',
#  '300347.XSHE',
#  '300408.XSHE',
#  '300413.XSHE',
#  '300433.XSHE',
#  '300498.XSHE',
#  '300601.XSHE',
#  '300628.XSHE',
#  '600000.XSHG',
#  '600004.XSHG',
#  '600009.XSHG',
#  '600010.XSHG',
#  '600011.XSHG',
#  '600015.XSHG',
#  '600016.XSHG',
#  '600018.XSHG',
#  '600019.XSHG',
#  '600025.XSHG',
#  '600027.XSHG',
#  '600028.XSHG',
#  '600029.XSHG',
#  '600030.XSHG',
#  '600031.XSHG',
#  '600036.XSHG',
#  '600038.XSHG',
#  '600048.XSHG',
#  '600050.XSHG',
#  '600061.XSHG',
#  '600066.XSHG',
#  '600068.XSHG',
#  '600085.XSHG',
#  '600089.XSHG',
#  '600104.XSHG',
#  '600109.XSHG',
#  '600111.XSHG',
#  '600115.XSHG',
#  '600118.XSHG',
#  '600170.XSHG',
#  '600176.XSHG',
#  '600177.XSHG',
#  '600183.XSHG',
#  '600188.XSHG',
#  '600196.XSHG',
#  '600208.XSHG',
#  '600219.XSHG',
#  '600221.XSHG',
#  '600233.XSHG',
#  '600271.XSHG',
#  '600276.XSHG',
#  '600297.XSHG',
#  '600299.XSHG',
#  '600309.XSHG',
#  '600332.XSHG',
#  '600340.XSHG',
#  '600346.XSHG',
#  '600352.XSHG',
#  '600362.XSHG',
#  '600369.XSHG',
#  '600372.XSHG',
#  '600383.XSHG',
#  '600390.XSHG',
#  '600398.XSHG',
#  '600406.XSHG',
#  '600436.XSHG',
#  '600438.XSHG',
#  '603019.XSHG',
#  '603156.XSHG',
#  '603160.XSHG',
#  '603259.XSHG',
#  '603260.XSHG',
#  '603288.XSHG',
#  '603369.XSHG',
#  '603501.XSHG',
#  '603658.XSHG',
#  '603799.XSHG',
#  '603833.XSHG',
#  '603899.XSHG',
#  '603986.XSHG',
#  '603993.XSHG']

# %%
data = jq.get_industries(name='jq_l2', date=None)

# %%
data.shape
# Out:
# (134, 2)

# %%
sjd = jq.normalize_code(['801161'])
sjd
# Out:
# ['801161.XSHG']

# %%
stocks = jq.get_industry_stocks('801161')

# %%
finance = jq.finance
df=finance.run_query(jq.query(finance.SW1_DAILY_PRICE).filter(finance.SW1_DAILY_PRICE.code=='801010').order_by(finance.SW1_DAILY_PRICE.date.desc()).limit(10))

# %%
df.head(10)
# Out:
#         id        date    code  name     open     high      low    close  \
# 0  1882564  2020-08-05  801010  农林牧渔  4592.18  4752.19  4557.18  4751.67
# 1  1882508  2020-08-04  801010  农林牧渔  4635.10  4706.44  4606.46  4614.72
# 2  1882452  2020-08-03  801010  农林牧渔  4522.76  4631.92  4522.76  4628.81
# 3  1882396  2020-07-31  801010  农林牧渔  4450.10  4501.67  4418.95  4497.91
# 4  1882368  2020-07-30  801010  农林牧渔  4451.98  4522.52  4443.35  4473.71
# 5  1882340  2020-07-29  801010  农林牧渔  4373.88  4449.25  4338.01  4449.25
# 6  1882284  2020-07-28  801010  农林牧渔  4287.35  4390.60  4268.64  4390.60
# 7  1882228  2020-07-27  801010  农林牧渔  4300.97  4360.60  4231.86  4266.04
# 8  1882172  2020-07-24  801010  农林牧渔  4330.12  4438.06  4221.89  4252.80
# 9  1882116  2020-07-23  801010  农林牧渔  4355.71  4378.89  4265.17  4351.63
#
#          volume         money  change_pct
# 0  3.465521e+09  4.938042e+10        2.97
# 1  3.783218e+09  5.139623e+10       -0.30
# 2  3.318729e+09  4.587483e+10        2.91
# 3  2.905085e+09  3.724722e+10        0.54
# 4  3.200686e+09  4.304110e+10        0.55
# 5  2.290718e+09  3.298845e+10        1.34
# 6  2.592023e+09  3.745557e+10        2.92
# 7  2.374905e+09  3.321078e+10        0.31
# 8  3.085015e+09  4.566760e+10       -2.27
# 9  2.267353e+09  3.240552e+10       -0.72

# %%
# Out:
#          date    open    high     low   close
# 0  2018-11-21  554.00  568.90  553.68  564.70
# 1  2018-11-22  565.15  567.33  558.00  564.50
# 2  2018-11-23  564.00  567.30  556.90  556.90
# 3  2018-11-26  558.00  560.20  552.00  552.11
# 4  2018-11-27  552.00  554.99  546.50  548.10
# 5  2018-11-28  550.85  559.19  545.50  557.00
# 6  2018-11-29  566.03  569.80  549.01  551.60
# 7  2018-11-30  557.00  568.89  553.00  565.00
# 8  2018-12-03  589.00  605.00  584.77  601.20
# 9  2018-12-04  602.99  604.26  595.00  602.23
